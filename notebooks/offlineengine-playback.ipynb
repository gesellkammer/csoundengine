# %%
import csoundengine as ce
# Out:
# end of score.		   overall amps:      0.0
# 	   overall samples out of range:        0
# 0 errors in performance

# %%
e = ce.OfflineEngine()
# Out:
# --Csound version 6.19 (double samples) May  8 2024
# [commit: 937aa495e250d758efaa28e9697a8b75237c80cd]
# libsndfile-1.2.2
# sr = 44100.0, kr = 689.062, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 442.0
# audio buffered in 256 sample-frame blocks
# writing 1024-byte blks of shorts to /tmp/csoundengine-e9_s9u6l.wav (WAV)
# SECTION 1:

# %%
tabnum = e.readSoundfile("/home/em/Lib/snd/samples/test/piano-pitchtest-2.flac", unique=False)

# %%
e.playSample(tabnum=tabnum, speed=2)
# Out:
# 19.0002

# %%
e.endtime
# Out:
# 5.214716553287982

# %%
e.playSample(tabnum=tabnum, speed=1.5, delay=1.5)
e.playSample(tabnum=tabnum, speed=1.3, delay=1.7)
e.playSample(tabnum=tabnum, speed=1., delay=2)
# Out:
# 19.0005

# %%
e.stop()
# Out:
# end of score.		   overall amps:  1.48463  0.00000
# 	   overall samples out of range:      135        0
# 0 errors in performance
# 512 1024 sample blks of shorts written to /tmp/csoundengine-acblpalv.wav (WAV)
# RenderJob(outfile='/tmp/csoundengine-acblpalv.wav', samplerate=44100, encoding='float32', starttime=0.0, endtime=0.0, process=None)

# %%
e = ce.OfflineEngine()
# Out:
# --Csound version 6.19 (double samples) May  8 2024
# [commit: 937aa495e250d758efaa28e9697a8b75237c80cd]
# libsndfile-1.2.2
# sr = 44100.0, kr = 689.062, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 442.0
# audio buffered in 256 sample-frame blocks
# writing 1024-byte blks of shorts to /tmp/csoundengine-cad5kbuo.wav (WAV)
# SECTION 1:

# %%
import sndfileio

# %%
samples, info = sndfileio.sndget("/home/em/Lib/snd/samples/speech/colours-german-male-1.flac")

# %%
e.makeTable(data=samples, sr=info.samplerate)
# Out:
# 100
