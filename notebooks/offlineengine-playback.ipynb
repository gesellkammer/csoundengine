# %%
import csoundengine as ce
import sndfileio
# Out:
# WARNING: Csound 7 support is experimental. Proceed at yout own risk

# %%
e = ce.OfflineEngine()
# Out:
# --Csound version 7.0 (double samples) Jan 16 2025
# [commit: f0bf77568df31b2ade4fe7fce654a5e6af5e8e45]
# libsndfile-1.2.0
# sr = 44100.0, kr = 689.062, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 442.0
# audio buffered in 256 sample-frame blocks
# writing 1024-byte blks of shorts to /tmp/csoundengine-smfkqprz.wav (WAV)
# SECTION 1:

# %%
tabnum = e.readSoundfile("/home/em/Lib/snd/samples/test/piano-pitchtest-2.flac")
e.playSample(tabnum=tabnum, speed=1)
e.stop()
# Out:
# resetting Csound instance
# 		   overall amps:  0.99997  0.00000
# 	   overall samples out of range:        0        0
# 0 errors in performance
# 512 1024 sample blks of shorts written to /tmp/csoundengine-smfkqprz.wav (WAV)
# RenderJob(outfile='/tmp/csoundengine-smfkqprz.wav', samplerate=44100, encoding='float32', starttime=0.0, endtime=0.0, process=None)

# %%
e = ce.OfflineEngine()
samps, sr = sndfileio.sndread("/home/em/Lib/snd/samples/test/piano-pitchtest-2.flac")
tabnum = e.makeTable(samps, sr)
e.playSample(tabnum=tabnum, speed=1)
e.stop()
# Out:
# --Csound version 7.0 (double samples) Jan 16 2025
# [commit: f0bf77568df31b2ade4fe7fce654a5e6af5e8e45]
# libsndfile-1.2.0
# sr = 44100.0, kr = 689.062, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 442.0
# audio buffered in 256 sample-frame blocks
# writing 1024-byte blks of shorts to /tmp/csoundengine-cr4iw4vf.wav (WAV)
# SECTION 1:
# 		   overall amps:      0.0
# 	   overall samples out of range:        0
# 0 errors in performance
# Elapsed time at end of performance: real: 17.921s, CPU: 1.388s
# resetting Csound instance
# 		   overall amps:  0.99997  0.00000
# 	   overall samples out of range:        0        0
# 0 errors in performance
# 512 1024 sample blks of shorts written to /tmp/csoundengine-cr4iw4vf.wav (WAV)
# RenderJob(outfile='/tmp/csoundengine-cr4iw4vf.wav', samplerate=44100, encoding='float32', starttime=0.0, endtime=0.0, process=None)

# %%
e._parsedInstrs
# Out:
# {}

# %%
e = ce.OfflineEngine()
samps, sr = sndfileio.sndread("/home/em/Lib/snd/samples/test/piano-pitchtest-2.flac")
tabnum = e.makeTable(samps, sr)
#e.playSample(tabnum=tabnum, speed=1)
#e.playSample(tabnum=tabnum, speed=1.5, delay=1.5)
#e.playSample(tabnum=tabnum, speed=1.3, delay=1.7)
event = e.playSample(tabnum=tabnum, speed=1., delay=2)
e.setp(event, 5, 3, delay=4)
e.automatep(event, 5, (0, 4, 0.5, 4, 1.5, 0.75, 3, 0.5), delay=5)
e.stop()
# Out:
# --Csound version 7.0 (double samples) Jan 16 2025
# [commit: f0bf77568df31b2ade4fe7fce654a5e6af5e8e45]
# libsndfile-1.2.0
# sr = 44100.0, kr = 689.062, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 442.0
# audio buffered in 256 sample-frame blocks
# writing 1024-byte blks of shorts to /tmp/csoundengine-yupy02pb.wav (WAV)
# SECTION 1:
# resetting Csound instance
# 		   overall amps:  0.99997  0.00000
# 	   overall samples out of range:        0        0
# 0 errors in performance
# 512 1024 sample blks of shorts written to /tmp/csoundengine-yupy02pb.wav (WAV)
# RenderJob(outfile='/tmp/csoundengine-yupy02pb.wav', samplerate=44100, encoding='float32', starttime=0.0, endtime=0.0, process=None)
