# %%
from csoundengine.offline import OfflineEngine
import sndfileio

# %%
e = OfflineEngine()
# Out:
# --Csound version 7.0 (double samples) Oct 28 2025
# [commit: 15afda0ba81a895a4e87ac3ef5fe476702b072bf]
# using libsndfile-1.2.2
# sr = 44100.0, kr = 689.062, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 440.0
# audio buffered in 256 sample-frame blocks
# writing 1024-byte blks of shorts to /tmp/csoundengine-50oo8had.wav (WAV)
# SECTION 1:

# %%
tabnum = e.readSoundfile("/home/em/Lib/snd/samples/test/piano-pitchtest-2.flac")
e.playSample(tabnum=tabnum, speed=1)
e.stop()
# Out:
# resetting Csound instance
# 		   overall amps:  0.99997  0.00000
# 	   overall samples out of range:        0        0
# 0 errors in performance
# 512 1024 sample blks of shorts written to /tmp/csoundengine-50oo8had.wav (WAV)
# RenderJob(outfile='/tmp/csoundengine-50oo8had.wav', samplerate=44100, encoding='float32', starttime=0.0, endtime=0.0, process=None)

# %%
e = OfflineEngine()
samps, sr = sndfileio.sndread("/home/em/Lib/snd/samples/test/piano-pitchtest-2.flac")
tabnum = e.makeTable(samps, sr)
e.playSample(tabnum=tabnum, speed=1)
e.stop()
# Out:
# --Csound version 7.0 (double samples) Oct 28 2025
# [commit: 15afda0ba81a895a4e87ac3ef5fe476702b072bf]
# using libsndfile-1.2.2
# sr = 44100.0, kr = 689.062, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 440.0
# audio buffered in 256 sample-frame blocks
# writing 1024-byte blks of shorts to /tmp/csoundengine-bjigryzn.wav (WAV)
# SECTION 1:
# 		   overall amps:      0.0
# 	   overall samples out of range:        0
# 0 errors in performance
# Elapsed time at end of performance: real: 1.420s, CPU: 1.234s
# resetting Csound instance
# 		   overall amps:  0.99997  0.00000
# 	   overall samples out of range:        0        0
# 0 errors in performance
# 512 1024 sample blks of shorts written to /tmp/csoundengine-bjigryzn.wav (WAV)
# RenderJob(outfile='/tmp/csoundengine-bjigryzn.wav', samplerate=44100, encoding='float32', starttime=0.0, endtime=0.0, process=None)

# %%
e = OfflineEngine()
samps, sr = sndfileio.sndread("/home/em/Lib/snd/samples/test/piano-pitchtest-2.flac")
tabnum = e.makeTable(samps, sr)
e.playSample(tabnum=tabnum, speed=1)
e.playSample(tabnum=tabnum, speed=1.5, delay=1.5)
e.playSample(tabnum=tabnum, speed=1.3, delay=1.7)
event = e.playSample(tabnum=tabnum, speed=1., delay=2)
e.setp(event, 5, 3, delay=4)
e.automatep(event, 5, (0, 4, 0.5, 4, 1.5, 0.75, 3, 0.5), delay=5)
e.stop()
# Out:
# --Csound version 7.0 (double samples) Oct 28 2025
# [commit: 15afda0ba81a895a4e87ac3ef5fe476702b072bf]
# using libsndfile-1.2.2
# sr = 44100.0, kr = 689.062, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 440.0
# audio buffered in 256 sample-frame blocks
# writing 1024-byte blks of shorts to /tmp/csoundengine-4k39e1p_.wav (WAV)
# SECTION 1:
# 		   overall amps:      0.0
# 	   overall samples out of range:        0
# 0 errors in performance
# Elapsed time at end of performance: real: 27.475s, CPU: 0.579s
# resetting Csound instance
# 		   overall amps:  1.61599  0.00000
# 	   overall samples out of range:      194        0
# 0 errors in performance
# 512 1024 sample blks of shorts written to /tmp/csoundengine-4k39e1p_.wav (WAV)
# RenderJob(outfile='/tmp/csoundengine-4k39e1p_.wav', samplerate=44100, encoding='float32', starttime=0.0, endtime=0.0, process=None)
