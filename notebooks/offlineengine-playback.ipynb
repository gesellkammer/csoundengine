# %%
import csoundengine as ce
import sndfileio
# Out:
# end of score.		   overall amps:      0.0
# 	   overall samples out of range:        0
# 0 errors in performance

# %%
e = ce.OfflineEngine()
# Out:
# --Csound version 6.19 (double samples) May  8 2024
# [commit: 937aa495e250d758efaa28e9697a8b75237c80cd]
# libsndfile-1.2.0
# sr = 44100.0, kr = 689.062, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 442.0
# audio buffered in 256 sample-frame blocks
# writing 1024-byte blks of shorts to /tmp/csoundengine-4nbjsbmz.wav (WAV)
# SECTION 1:

# %%
tabnum = e.readSoundfile("/home/em/Lib/snd/samples/test/piano-pitchtest-2.flac")
e.playSample(tabnum=tabnum, speed=1)
e.stop()
# Out:
# end of score.		   overall amps:  0.99997  0.00000
# 	   overall samples out of range:        0        0
# 0 errors in performance
# 512 1024 sample blks of shorts written to /tmp/csoundengine-4nbjsbmz.wav (WAV)
# RenderJob(outfile='/tmp/csoundengine-4nbjsbmz.wav', samplerate=44100, encoding='float32', starttime=0.0, endtime=0.0, process=None)

# %%
e = ce.OfflineEngine()
samps, sr = sndfileio.sndread("/home/em/Lib/snd/samples/test/piano-pitchtest-2.flac")
tabnum = e.makeTable(samps, sr)
e.playSample(tabnum=tabnum, speed=1)
e.stop()
# Out:
# --Csound version 6.19 (double samples) May  8 2024
# [commit: 937aa495e250d758efaa28e9697a8b75237c80cd]
# libsndfile-1.2.0
# sr = 44100.0, kr = 689.062, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 442.0
# audio buffered in 256 sample-frame blocks
# writing 1024-byte blks of shorts to /tmp/csoundengine-d4903a4p.wav (WAV)
# SECTION 1:
# end of score.		   overall amps:  0.99997  0.00000
# 	   overall samples out of range:        0        0
# 0 errors in performance
# 512 1024 sample blks of shorts written to /tmp/csoundengine-d4903a4p.wav (WAV)
# RenderJob(outfile='/tmp/csoundengine-d4903a4p.wav', samplerate=44100, encoding='float32', starttime=0.0, endtime=0.0, process=None)

# %%
e = ce.OfflineEngine()
samps, sr = sndfileio.sndread("/home/em/Lib/snd/samples/test/piano-pitchtest-2.flac")
tabnum = e.makeTable(samps, sr)
#e.playSample(tabnum=tabnum, speed=1)
#e.playSample(tabnum=tabnum, speed=1.5, delay=1.5)
#e.playSample(tabnum=tabnum, speed=1.3, delay=1.7)
event = e.playSample(tabnum=tabnum, speed=1., delay=2)
e.setp(event, 5, 3, delay=4)
e.stop()
# Out:
# --Csound version 6.19 (double samples) May  8 2024
# [commit: 937aa495e250d758efaa28e9697a8b75237c80cd]
# libsndfile-1.2.0
# sr = 44100.0, kr = 689.062, ksmps = 64
# 0dBFS level = 1.0, A4 tuning = 442.0
# audio buffered in 256 sample-frame blocks
# writing 1024-byte blks of shorts to /tmp/csoundengine-zy5xnnu4.wav (WAV)
# SECTION 1:
# end of score.		   overall amps:  0.98401  0.00000
# 	   overall samples out of range:        0        0
# 0 errors in performance
# 512 1024 sample blks of shorts written to /tmp/csoundengine-zy5xnnu4.wav (WAV)
# RenderJob(outfile='/tmp/csoundengine-zy5xnnu4.wav', samplerate=44100, encoding='float32', starttime=0.0, endtime=0.0, process=None)
